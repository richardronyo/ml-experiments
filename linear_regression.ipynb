# %%
import numpy as np
import matplotlib.pyplot as plt
from LinearRegression.LinReg import LinearRegression

# %%
#2D Dataset
X = np.random.rand(100, 1).flatten()
noise = np.random.uniform(-1, 1, 100)

y_train = 4 + (3 * (X + random_vals))
y_true = 4 + (3 * X)

plt.scatter(X, y_train, color = 'blue', label = 'Training Dataset')
plt.plot(X, y_true, color = 'red', label = 'y = 4 + 3x')

plt.legend()
