# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.rand(100, 1)
y = 4 + (3 * X * np.random.rand(1))

# %%
plt.scatter(X, y)

# %%
X_b = np.c_[np.ones((100, 1)), X]
theta = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

theta
# Out:
# array([[4.        ],
#        [2.26717302]])

# %%
X_test = np.array([[0], [5]])
X_final = np.c_[np.ones((2, 1)), X_test]

y_predict = X_final.dot(theta)

y_predict
# Out:
# array([[ 4.        ],
#        [15.33586512]])

# %%
plt.scatter(X, y)
plt.plot(X_test, y_predict, 'r')
plt.axis([0, 2, 0, 15])
# Out:
# (np.float64(0.0), np.float64(2.0), np.float64(0.0), np.float64(15.0))

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
lin_reg.intercept_
# Out:
# array([4.])

# %%
lin_reg.coef_
# Out:
# array([[2.26717302]])

# %%
lin_reg.predict(X_test)
# Out:
# array([[ 4.        ],
#        [15.33586512]])
